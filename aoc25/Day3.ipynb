# %% [markdown]
# ## Day 3
# ### Part 1

# %%
batteries = [
'987654321111111',
'811111111111119',
'234234234234278',
'818181911112111']

# %%
jolts = []

for battery in batteries:
    max1 = -1
    max2 = -1
    pos = -1
    joltage = ''

    for position in range(0, (len(battery) -1)):
       jolt = int((battery[position]))
       if jolt > max1:
           max1 = jolt
           pos = position 
           joltage = str(max1)

    for position2 in range(pos +1, len(battery)):
        jolt2 = int((battery[position2]))
        if jolt2 > max2:
            max2 = jolt2
        if position2 == (len(battery)):
            joltage = joltage + str(max2)

            
joltage
                   

                   

  

#maybe using max.value to find the first maximum value in length -1 and then finding the second myáx value with an if statement
# Out:
# '9'
