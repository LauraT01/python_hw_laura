# %% [markdown]
# ## Day 3
# ### Part 1
#
# had to rethink my approach

# %%
def read_file_into_lines(file_path):
    lines = []
    with open(file_path, 'r') as infile:
        for line in infile.readlines():
            cleaned = line.rstrip()
            lines.append(cleaned)
    return lines

# %%
batteries =[ #read_file_into_lines('/Users/laura/Desktop/python_hw/aoc25/input_day3')
'987654321111111',
'811111111111119',
'234234234234278',
'818181911112111']

# %%
jolts = 0

for battery in batteries:
    max1 = max(battery[:-1])          
    pos = battery.index(max1)         

    if pos + 1 < len(battery):
        max2 = max(battery[pos + 1:])
    else:
        max2 = battery[-1]                  

    joltage = str(max1) + str(max2)
    jolts = jolts + int(joltage)

print(jolts)
# Out:
# 357

# %% [markdown]
# ### Part 2

# %%
jolts = 0

for battery in batteries:
    max1 = max(battery[:-1])          
    pos = battery.index(max1)
    remaining_battery = battery[pos : -1]   

    for jolt in range (11):  
        max_jolt = max(remaining_battery)   
        print(max_jolt)       
        pos = battery.index(max_jolt)
        remaining_battery = battery[pos : -1] 
        joltage = joltage + str(max_jolt)
    jolts = jolts + int(joltage)     

    ##if pos + 1 < len(battery):
    #max2 = max(battery[pos + 1:])
    #pos = battery.index(max2)
#
    ##if pos + 1 < len(battery):
    #max3 = max(battery[pos + 1:])
    #pos = battery.index(max3)
#
    ##if pos + 1 < len(battery):
    #max4 = max(battery[pos + 1:])
    #pos = battery.index(max4)
#
    ##if pos + 1 < len(battery):
    #max5 = max(battery[pos + 1:])
    #pos = battery.index(max5)
#
    ##if pos + 1 < len(battery):
    #max6 = max(battery[pos + 1:])
    #pos = battery.index(max6)    
    ##i  pos + 1 < len(battery):
    #max7 = max(battery[pos + 1:])
    #pos = battery.index(max7)    
    ##i  pos + 1 < len(battery):
    #max8 = max(battery[pos + 1:])
    #pos = battery.index(max8)    
    ##i  pos + 1 < len(battery):
    #max9 = max(battery[pos + 1:])
    #pos = battery.index(max9)    
    ##i  pos + 1 < len(battery):
    #max10 = max(battery[pos + 1:])
    #pos = battery.index(max10)   
    ##i  pos + 1 < len(battery):
    #max11 = max(battery[pos + 1:])
    #pos = battery.index(max11)   
    ##i  pos + 1 < len(battery):
    #max12 = max(battery[pos + 1:])
    #pos = battery.index(max12)   
    ##else:
    ##    max2 = battery[-11]
    ##    max3 = battery[-10]  
    ##    max4 = battery[-9]  
    ##    max5 = battery[-8]  
    ##    max6 = battery[-7]  
    ##    max7 = battery[-6] 
    #    max8 = battery[-5]  
    #    max9 = battery[-4]  
    #    max10 = battery[-3]  
    #    max11 = battery[-2]  
    #    max12 = battery[-1]  
        

           








    #joltage = str(max1) + str(max2) + str(max3) + str(max4) + str(max5) + str(max6) + str(max7) + str(max8) + str(max9) + str(max10) + str(max11) + str(max12)
    #jolts = jolts + int(joltage)

print(jolts)
# Out:
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[25], line 78
#      14     jolts = jolts + int(joltage)
#      16     ##if pos + 1 < len(battery):
#      17     #max2 = max(battery[pos + 1:])
#      18     #pos = battery.index(max2)
#    (...)     76     #joltage = str(max1) + str(max2) + str(max3) + str(max4) + str(max5) + str(max6) + str(max7) + str(max8) + str(max9) + str(max10) + str(max11) + str(max12)
#      77     #jolts = jolts + int(joltage)
# ---> 78 jolt = (jolts / 12)
#      79 print(jolts)
#
# OverflowError: integer division result too large for a float
