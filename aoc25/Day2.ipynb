# %% [markdown]
# ## December 2nd
# ### Part 1

# %%
IDs = ('3737332285-3737422568,5858547751-5858626020,166911-236630,15329757-15423690,753995-801224,1-20,2180484-2259220,24-47,73630108-73867501,4052222-4199117,9226851880-9226945212,7337-24735,555454-591466,7777695646-7777817695,1070-2489,81504542-81618752,2584-6199,8857860-8922218,979959461-980003045,49-128,109907-161935,53514821-53703445,362278-509285,151-286,625491-681593,7715704912-7715863357,29210-60779,3287787-3395869,501-921,979760-1021259')
    
    
    
    
    #'11-22,95-115,998-1012,1188511880-1188511890,222220-222224, 1698522-1698528,446443-446449,38593856-38593862,565653-565659, 824824821-824824827,2121212118-2121212124')

# %%
ranges = list(IDs.split(','))

# %%
ranges
# Out:
# ['3737332285-3737422568',
#  '5858547751-5858626020',
#  '166911-236630',
#  '15329757-15423690',
#  '753995-801224',
#  '1-20',
#  '2180484-2259220',
#  '24-47',
#  '73630108-73867501',
#  '4052222-4199117',
#  '9226851880-9226945212',
#  '7337-24735',
#  '555454-591466',
#  '7777695646-7777817695',
#  '1070-2489',
#  '81504542-81618752',
#  '2584-6199',
#  '8857860-8922218',
#  '979959461-980003045',
#  '49-128',
#  '109907-161935',
#  '53514821-53703445',
#  '362278-509285',
#  '151-286',
#  '625491-681593',
#  '7715704912-7715863357',
#  '29210-60779',
#  '3287787-3395869',
#  '501-921',
#  '979760-1021259']

# %%
invalidIDs = 0
sum = 0
for r in ranges:
    start, stop = r.split('-')
    #print(start, stop)
    for number in range(int(start), int(stop) + 1):
        #print(number)
        ID = str(number) 
        half = (len(ID) // 2)
        if ID[half:] == ID[:half]:
            invalidIDs = invalidIDs +1
            sum = sum + int(ID)
        

print(invalidIDs)
sum
# Out:
# 584
# 38437576669

# %% [markdown]
# ### Part 2

# %%
newIDs = ('11-22,95-115,998-1012,1188511880-1188511890,222220-222224, 1698522-1698528,446443-446449,38593856-38593862,565653-565659, 824824821-824824827,2121212118-2121212124')

new_ranges = list(newIDs.split(','))

# %%
new_invalidIDs = 0
new_sum = 0
pattern = ''

for new_r in new_ranges:
    new_start, new_stop = new_r.split('-')
    newID = str(number)
    #if len(newID) % 2 == 0:
    for number in range(int(new_start), int(new_stop) + 1):
        half2 = (len(ID) // 2)
        str(number)
        pattern = [number, half2 + 1]
        print(pattern)
# Out:
# [11, 4]
# [12, 4]
# [13, 4]
# [14, 4]
# [15, 4]
# [16, 4]
# [17, 4]
# [18, 4]
# [19, 4]
# [20, 4]
# [21, 4]
# [22, 4]
# [95, 4]
# [96, 4]
# [97, 4]
# [98, 4]
# [99, 4]
# [100, 4]
# [101, 4]
# [102, 4]
# [103, 4]
# [104, 4]
# [105, 4]
# [106, 4]
# [107, 4]
# [108, 4]
# [109, 4]
# [110, 4]
# [111, 4]
# [112, 4]
# [113, 4]
# [114, 4]
# [115, 4]
# [998, 4]
# [999, 4]
# [1000, 4]
# [1001, 4]
# [1002, 4]
# [1003, 4]
# [1004, 4]
# [1005, 4]
# [1006, 4]
# [1007, 4]
# [1008, 4]
# [1009, 4]
# [1010, 4]
# [1011, 4]
# [1012, 4]
# [1188511880, 4]
# [1188511881, 4]
# [1188511882, 4]
# [1188511883, 4]
# [1188511884, 4]
# [1188511885, 4]
# [1188511886, 4]
# [1188511887, 4]
# [1188511888, 4]
# [1188511889, 4]
# [1188511890, 4]
# [222220, 4]
# [222221, 4]
# [222222, 4]
# [222223, 4]
# [222224, 4]
# [1698522, 4]
# [1698523, 4]
# [1698524, 4]
# [1698525, 4]
# [1698526, 4]
# [1698527, 4]
# [1698528, 4]
# [446443, 4]
# [446444, 4]
# [446445, 4]
# [446446, 4]
# [446447, 4]
# [446448, 4]
# [446449, 4]
# ...

# %%
new_sum
# Out:
# 0
