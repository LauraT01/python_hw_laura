# %% [markdown]
# ## Day 6
# ### Puzzle 1

# %%
def read_file_into_lines(file_path):
    lines = []
    with open(file_path, 'r') as infile:
        for line in infile.readlines():
            cleaned = line.rstrip()
            lines.append(cleaned)
    return lines

# %%
problems = read_file_into_lines('/Users/laura/Desktop/python_hw/aoc25/input_day6')


#['123 328  51 64', 
# '45 64  387 23',
# ' 6 98  215 314',
#'*   +   *   +'  ]

# %%
rows = []
for problem in problems:
    row = problem.split()
    rows.append(row)

# %%
rows
# Out:
# [['724',
#   '2384',
#   '57',
#   '32',
#   '142',
#   '25',
#   '89',
#   '2',
#   '45',
#   '221',
#   '382',
#   '9887',
#   '24',
#   '64',
#   '723',
#   '66',
#   '31',
#   '69',
#   '747',
#   '8514',
#   '833',
#   '949',
#   '585',
#   '437',
#   '867',
#   '2',
#   '43',
#   '92',
#   '11',
#   '84',
#   '58',
#   '661',
#   '73',
#   '2',
#   '7',
#   '54',
#   '72',
#   '81',
#   '338',
#   '72',
#   '297',
#   '5',
#   '119',
#   '83',
#   '83',
#   '949',
#   '874',
#   '532',
#   '33',
#   '1',
#   '4',
#   '7',
#   '97',
#   '3',
#   '42',
#   '92',
#   '99',
#   '33',
#   '78',
#   '499',
#   '8',
#   '71',
#   '823',
#   '6',
#   '6',
#   '99',
#   '7395',
#   '63',
#   '8718',
#   '291',
#   '13',
#   '19',
#   '388',
#   '7',
#   '826',
#   '83',
#   '43',
#   '431',
#   '393',
#   '73',
#   '78',
#   '53',
#   '29',
#   '6',
#   '2',
#   '9',
#   '54',
#   '947',
#   '5319',
#   '52',
#   '2851',
#   '94',
#   '53',
#   '913',
#   '431',
#   '186',
#   '46',
# ...

# %%
equation = rows[0][0] + rows[-1][0] + rows[1][0] + rows[-1][0] + rows[2][0]

# %%
number_prob = len(rows[0])

# %%
total = 0

for column in range(number_prob):
    numbers = []
    for row in rows[:-1]:
        numbers.append(int(row[column]))

    operator = rows[-1][col]

    if operator == "+":
        result = sum(numbers)
    else: 
        result = 1
        for n in numbers:
            result = result * n
    total = total + result



    #if operator == '-':
    
    #if operator == ':':

# %%
total
# Out:
# 6635273135233
