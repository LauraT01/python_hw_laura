# %% [markdown]
# ### Rosalind IPRB
# Mendel's First Law
# Given: Three positive integers k, m, and n, representing a population containing k+m+n organisms: k individuals are homozygous dominant for a factor, m are heterozygous, and n are homozygous recessive.
#
# Return: The probability that two randomly selected mating organisms will produce an individual possessing a dominant allele (and thus displaying the dominant phenotype). Assume that any two organisms can mate.
#
# looking for the probability that the offspring has the dominant phenotype
# k = hom. dominant, m = heterozygous, n = hom. recessive, N = whole pop

# %%
#AA = homozygous dominant first parent
#Aa = heterozygous first parent
#aa = homozygous recessive first parent

k = 29 
m = 25
n = 30
N = k + m + n

AA = k/N

Aa = (m/N * (k/(N - 1))) + (m/N *((m-1)/(N - 1))* 0.75) + (m/N * ((n)/(N - 1))* 0.5)

aa = (n/N * (k/(N-1))) + (n/N * (m/(N - 1))* 0.5)

total = AA + Aa + aa

print(total)
# Out:
# 0.7461273666092944

# %% [markdown]
# ### Rosalind SUBS¶
#
# Given: Two DNA strings s and t (each of length at most 1 kbp).
#
# Return: All locations of t as a substring of s

# %%
s = '...'
t = 'TCACCATTC'

for i in range(len(s)):
    if t == s[i: i+len(t)]:
        print(i+1)
# Out:
# 10
# 113
# 151
# 158
# 191
# 198
# 240
# 255
# 262
# 306
# 313
# 320
# 418
# 425
# 432
# 484
# 577
# 814
# 821
# 828

# %% [markdown]
# ### Rosalind FIB
# Given: Positive integers n≤40 and k≤5.
#
# Return: The total number of rabbit pairs that will be present after n months,
# if we begin with 1 pair and in each generation, every pair of reproduction-age rabbits
# produces a litter of k rabbit pairs (instead of only 1 pair).

# %%
#p = pairs in the end
#F1 = pairs last month
#F2 = pairs 2 months ago
n = 33
k = 2
p = 0
F1 = 1
F2 = 1

if n == 1 or n == 2:
    print(1)
else:
    for month in range(3, n + 1):
        p = F2 + (k * F1)
        F1 = F2
        F2 = p

    print(p)
# Out:
# 2863311531
