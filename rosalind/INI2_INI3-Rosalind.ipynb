# %%
a = 987 
b = 841

# %%
c = (a**2 + b**2)

# %%
c
# Out:
# 1681450

# %%
s = 'Wws6U8WH3nhiEbUrOXgFQCNe5Sgx9s1PcIQ25Y9q77s7qXTsx7On5EL3TheclaE58g1PfRE8RQFgIs1LftDYGMjAqVMZD4yyjIioRvVSwQ95lt3alcinousibRkvc0GTAz7tqNZKd7dgQAvmv1hgo2EfveyO2aVRyGWPA0sS8UvwvtScx5'

# %%
string1 = s[56:62]
string2 = s[111:119]

# %%
string1
# Out:
# 'Thecla'

# %%
string2
# Out:
# 'alcinous'

# %%
print(s[56:62] + " " + s[111:119])
# Out:
# Thecla alcinous
