# %%
DNA = "..."

# %%
RNA = print(DNA.replace("T","U"))
# Out:
# ...

# %% [markdown]
# #### achieving the same outout with loops and conditionals

# %%
DNA = "..."
RNA = ""
base = ["A", "T", "C", "G"]

for base in DNA:
    if base == "T":
        RNA = RNA + "U"
    else:
        RNA = RNA + base
print(RNA)
# Out:
# ...
