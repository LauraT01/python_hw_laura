# %% [markdown]
# # Rosalind DNA exercise

# %%
s = "..."

# %%
count_A = s.count('A')
count_C = s.count('C')
count_G = s.count('G')
count_T = s.count('T')

# %%
print(count_A, count_C, count_G, count_T)
# Out:
# 236 255 259 231

# %% [markdown]
# ## solving it again, this time with a loop

# %%
s = "..."

# %%
nucleotides = ["A", "C", "T", "G"]
for n in nucleotides:
    count = s.count(n)
    print(n, ":", count)
# Out:
# A : 236
# C : 255
# T : 231
# G : 259
